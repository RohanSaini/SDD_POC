# %%
from elasticsearch import Elasticsearch
es = Elasticsearch()
import json

# %%
coitest = [
"What is a court of inquiry?",
"Give definition of court of inquiry?",
"What are the cases which are necessarily required to be investigated by a court of inquiry?",
"Mandotory cases to be tries under court of inquiry?",
"Which cases can be tried under court of inquiry?",
"Can AWL/OSL beyond 30 days be tried by court of inquiry?",
"Can PoW be excercised by court of inquiry?",
"Does Absent with out leave beyond 30 days be tried under court of inquiry?",
"Can collective Fine be tried by court of Inquiry?",
"Does cases of Financial Irregulartities be tried by court of Inquiry?",
"Can Fatal/Grievious injuries to Military Personnel be tried by court of inquiry?",
"Can Injury to civilians be tried by court of inquiry and under what regulation it is given? ",
"Does the case for Assault and Affray be tried under Court of Inquiry?",
"Can unnatural Death be tried under court of inquiry?",
"What different types of Breaches of Discpline be tried under court of inquiry?",
"Can loss of I-card be tried under court of inquiry?",
"Can death of animal be tried under court of inquiry?",
"Can destruction by fire be tried by court of inquiry?",
"Does collective insubordination be tried under court of inquiry?",
"Can MT accidents resulting in death/serious injury be tried under court of inquiry?",
"can suscide be tried under court of inquiry?",
"can attempted or suspected suicicde be tried under court of inquiry?",
"cases wrt murder and rape be tried under court of inquiry?",
"cases wrt murder and rape be tried under court of inquiry?",
"what section of army act are related to cASESof murder or rape?",
"can loss of secret and confidential documents be tried by court of inquiry?",
"can loss of stores and public money be tried by court of inquiry?",
"what regulalation of Army para is referred for the loss of stores and public money?",
"can cases for explosion and accidents be tried under court of inquiry?",
"can cases for explosion and accidents be tried under court of inquiry?",
"can finding of guilty or Not Guilty or award of sentence be part of court of inquiry?"

]

# %%
for i,ques in enumerate(coitest):
    result = es.search(index="coidocindex", body={ "query": {
            "multi_match": {
                "query":    ques,
                "fields":   [ "questions","doc" ]
            }
          }})
    if len(result["hits"]["hits"])> 0:
        print("Question ===> "+ str(ques))
        print("=>" + result["hits"]["hits"][0]["_source"]["tag"])
        print(result["hits"]["hits"][0]["_source"]["doc"])
        with open("coitest.json", "a") as f:
            f.write(json.dumps({
                "Question":str(ques),
                "Source of Answer": result["hits"]["hits"][0]["_source"]["tag"],
                "Answer":result["hits"]["hits"][0]["_source"]["doc"]
            })+',')
    else:
        print ('========')
    print("-----------------------------------------------------------")
# Out:
# Question ===> What is a court of inquiry?
# =>COI 4 type of Inquires
# a)   Unit Court of Inquiry : - Court of Inquiry assembled on orders of Commanding Officer of a unit is called as Unit Court of Inquiry. <br>(b)   Departmental Inquiry : An inquiry assembled on orders of Head of any Arm, Service or Department to bring out the shortcomings or irregularities in quantitative and qualitative terms only is called the Departmental Inquiry. <br> (c)  Staff Court of Inquiry : A Staff Court of Inquiry may be assembled by a Formation Commander to inquire into matters concerning discipline. He may order a Staff C of I in addition to a Departmental Inquiry should he consider that disciplinary proceedings, may be a likely outcome of a departmental inquiry.
# -----------------------------------------------------------
# Question ===> Give definition of court of inquiry?
# =>COI 1
# ...

# %%
test40 = [
    "Does Criminal Force differ from assault?",
"Are Criminal Force and assault two different things?",
"Is there any difference between criminal force and assault?",
"What is the difference between criminal force and assault?",
"What is the meaning of term criminal force and assault?",
"Explain criminal force and assault?",
"I dont see any difference between criminal force and assault.",
"Give me an example of use of criminal force.",
"What will be an appropriate example of criminal force?",
"Illustrate with an example meaning of term criminal force?",
"Give a practical instance of criminal force.",
"Give me an example of assault.",
"What will be an appropriate example of assault?",
"Illustrate with an example meaning of term assault.",
"Give a practical instance of assault.",
"Is criminal force and assault similar?",
"Criminal Force and assault are alike?",
"Is criminal force and assault interchangeable?",
"Is there any similarity between criminal force and assault?",
"What is the relation between criminal force and assault?",
"What are the ingredients of a charge under Sec 40 (a)?",
"What needs to be proved to ensure conviction for an offence of use of criminal force to superior officer?",
"How to prove a charge of use of criminal force?",
"Who is a superior officer?",
"What does a superior officer mean?",
"Can Maj A after slapping Lt Col B defend himself by saying that he slapped Lt Col B in private defence?",
"Is use of criminal force in private defence condonable?",
"Can a Army personnel go scot free after using criminal force to his superior officer?",
"Can a junior take defence of provocation for using criminal force to superior officer?",
"Is provocation a defence for using criminal force?",
"Can two persons be tried jointly for using criminal force to or assaulting a superior officer?",
"Is joint trial permissible for a charge framed under Sec 40 (a) of Army Act?",
"What is required to be prove a joint charge under Sec 40 (a)?",
"What is required to prove joint charge of criminal force or assault?",
"Explain Superior Officer as used in Sec 40(a) of Army Act?",
"What is the meaning of Superior Officer as used in Sec 40(a) of Army Act?",
"In what sense word Superior Officer has been used in Sec 40(a) of Army Act?",
"What is the punishment for using criminal force to or assaulting Superior Officer?",
"How much sentence a person will get for using criminal force to or assaulting a Superior Officer?",
"What is the maximum sentence for using criminal force to a superior officer?",
"What is the maximum punishment for using criminal force to a superior officer?",
"What does execution of his office mean?",
"What is the meaning of Execution of his office?",
"Explain words in execution of his office?",
"Explain Threatening Language?",
"What does Threatening Language mean?",
"What do you understand by Threatening Language?",
"What are the essentials of a charge under Sec 40 (b) of Army Act?",
"What are the requirements to prove a charge under Sec 40 (b) of Army Act?",
"What is the punishment for threatening a superior officer?",
"What is the maximum punishment for threatening a superior officer?",
"What does insubordinate language mean?",
"What is the meaning of insubordinate language?",
"When is use of threatening language an offence?",
"When is insubordinate language an offence?",
"When can a person be charged for using threatening language or insubordinate language?",
"Can the charge of insubordinate language be framed without words having been spoken?",
"Does Criminal Force differ from assault?",
"Are Criminal Force and assault two different things?",
"Is there any difference between criminal force and assault?",
"What is the difference between criminal force and assault?",
"What is the meaning of term criminal force and assault?",
"Explain criminal force and assault?",
"I dont see any difference between criminal force and assault.",
"Give me an example of use of criminal force.",
"What will be an appropriate example of criminal force?",
"Illustrate with an example meaning of term criminal force?",
"Give a practical instance of criminal force.",
"Give me an example of assault.",
"What will be an appropriate example of assault?",
"Illustrate with an example meaning of term assault.",
"Give a practical instance of assault.",
"Is criminal force and assault similar?",
"Criminal Force and assault are alike?",
"Is criminal force and assault interchangeable?",
"Is there any similarity between criminal force and assault?",
"What is the relation between criminal force and assault?",
"What are the ingredients of a charge under Sec 40 (a)?",
"What needs to be proved to ensure conviction for an offence of use of criminal force to superior officer?",
"How to prove a charge of use of criminal force?",
"Who is a superior officer?",
"What does a superior officer mean?",
"Can Maj A after slapping Lt Col B defend himself by saying that he slapped Lt Col B in private defence?",
"Is use of criminal force in private defence condonable?",
"Can a Army personnel go scot free after using criminal force to his superior officer?",
"Can a junior take defence of provocation for using criminal force to superior officer?",
"Is provocation a defence for using criminal force?",
"Can two persons be tried jointly for using criminal force to or assaulting a superior officer?",
"Is joint trial permissible for a charge framed under Sec 40 (a) of Army Act?",
"What is required to be prove a joint charge under Sec 40 (a)?",
"What is required to prove joint charge of criminal force or assault?",
"Explain Superior Officer as used in Sec 40(a) of Army Act?",
"What is the meaning of Superior Officer as used in Sec 40(a) of Army Act?",
"In what sense word Superior Officer has been used in Sec 40(a) of Army Act?",
"What is the punishment for using criminal force to or assaulting Superior Officer?",
"How much sentence a person will get for using criminal force to or assaulting a Superior Officer?",
"What is the maximum sentence for using criminal force to a superior officer?",
"What is the maximum punishment for using criminal force to a superior officer?",
"What does execution of his office mean?",
"What is the meaning of Execution of his office?",
"Explain words in execution of his office?",
"Explain Threatening Language?",
"What does Threatening Language mean?",
"What do you understand by Threatening Language?",
"What are the essentials of a charge under Sec 40 (b) of Army Act?",
"What are the requirements to prove a charge under Sec 40 (b) of Army Act?",
"What is the punishment for threatening a superior officer?",
"What is the maximum punishment for threatening a superior officer?",
"What does insubordinate language mean?",
"What is the meaning of insubordinate language?",
"When is use of threatening language an offence?",
"When is insubordinate language an offence?",
"When can a person be charged for using threatening language or insubordinate language?",
"Can the charge of insubordinate language be framed without words having been spoken?"

]

# %%
for i,ques in enumerate(test40):
    result = es.search(index="aa40n41", body={ "query": {
            "multi_match": {
                "query":    ques,
                "fields":   [ "questions","doc" ]
            }
          }})
    if len(result["hits"]["hits"])> 0:
        print("Question ===> "+ str(ques))
        print("=>" + result["hits"]["hits"][0]["_source"]["tag"])
        print(result["hits"]["hits"][0]["_source"]["doc"])
        with open("aa40test.json", "a") as f:
            f.write(json.dumps({
                "Question":str(ques),
                "Source of Answer": result["hits"]["hits"][0]["_source"]["tag"],
                "Answer":result["hits"]["hits"][0]["_source"]["doc"]
            })+',')
    else:
        print ('========')
    print("-----------------------------------------------------------")
# Out:
# Question ===> Does Criminal Force differ from assault?
# =>assult and criminal force similarity act 40 note 2 a
# An 'assault' is something less than the use of criminal force; the force being cut short before the blow actually falls. It seems to consist in an attempt or offer by a person having present ability, with force to do any hurt or violence to the person of another, and it is committed whenever a well founded apprehension of peril from a force partially or fully put in motion is created, e.g., when a person draws a bayonet or otherwise makes a show of violence against a superior but not when net is behind the bars or at such a distance as to rule out at the moment any actual use of criminal force An assault is thus included in every use of criminal force, and is an intermediate stage thereof
# -----------------------------------------------------------
# Question ===> Are Criminal Force and assault two different things?
# ...

# %%
test41 = [
    "What is disobedience to superior officer?",
"under which act can a person who confronts the orders of senior officer be tried? ",
"who all can be tried under army act 41?",
"which act is applied for disobedience of oral orders by senior officer ? ",
"can disobedience to superior officer be convicted by court martial?",
"what is the punishment given for army act 41?",
"what is the punishment given for disobedience to superior officer?",
"Can the term of punishment be extended? If so then what is the period?",
"Can the offence under AA 41 be dealt with summarily under AA 80?",
"Can the offence under AA 41 be dealt with summarily under AA 83?",
"Can the offence under AA 41 be dealt with summarily under AA 84?",
"can the offence committed under AA 41 be made the subject of joint charge?",
"what is the meaning of lawfull command?",
"should the command relate to the military duty?",
"Should the disobedience be referenced with time to which the command is to be obeyed?",
"If a person expressess an intention  not to obey and is immediately confined , the ncan that person be trailed under this act?",
"if so then under which act he can be charged?",
"Who all can not charged under this act?"

]

# %%
for i,ques in enumerate(test41):
    result = es.search(index="aa40n41", body={ "query": {
            "multi_match": {
                "query":    ques,
                "fields":   [ "questions","doc" ]
            }
          }})
    if len(result["hits"]["hits"])> 0:
        print("Question ===> "+ str(ques))
        print("=>" + result["hits"]["hits"][0]["_source"]["tag"])
        print(result["hits"]["hits"][0]["_source"]["doc"])
        with open("aa41test.json", "a") as f:
            f.write(json.dumps({
                "Question":str(ques),
                "Source of Answer": result["hits"]["hits"][0]["_source"]["tag"],
                "Answer":result["hits"]["hits"][0]["_source"]["doc"]
            })+',')
    else:
        print ('========')
    print("-----------------------------------------------------------")
# Out:
# Question ===> What is disobedience to superior officer?
# =>act 41 note 5 b
# Disobedience of a lawful order given by a person who is not a superior officer within the meaning of AA.s.3(xxiii) may be punishable under AA.s.63 if the disobedience was prejudicial to good order and military discipline; for instance, a civilian cannot give a 'lawful command' under this section to a soldier employed under him; but it may well be the soldier's duty as such to do the act indicated, and, if so, he may be punished for not doing it under AA.s.63. The particulars of the charge should clearly show that the disobedience was prejudicial to good order and military discipline because the soldier had been placed under the orders of the civilian by a superior military authority
# -----------------------------------------------------------
# Question ===> under which act can a person who confronts the orders of senior officer be tried?
# =>act 41 main text 1
# ...

# %%
for i,ques in enumerate(coitest):
    result = es.search(index="incidentreport", body={ "query": {
            "multi_match": {
                "query":    ques,
                "fields":   [ "tag","context" ]
            }
          }})
    if len(result["hits"]["hits"])> 0:
        
        #print(result["hits"]["hits"][0]["_source"]["doc"])
        with open("incidenttestforApp-A.json", "a") as f:
            if float(result["hits"]["hits"][0]["_score"] > 5):
                print("Question ===> "+ str(ques))
                print("score ===> "+ str(result["hits"]["hits"][0]["_score"]))
                print("Answer =>" + result["hits"]["hits"][0]["_source"]["tag"])
                f.write(json.dumps({
                "Question":str(ques),
                "Score of Answer": result["hits"]["hits"][0]["_score"],
                "Answer":result["hits"]["hits"][0]["_source"]["tag"]
            })+',')
            else:
                f.write(json.dumps({
                "Question":str(ques),
                "Score of Answer": result["hits"]["hits"][0]["_score"],
                "Answer":'According to App A it is not mad to report'
            })+',')
                print("Question ===> "+ str(ques))
                print('According to App A it is not mad to report');
            
    else:
        print ('========')
    print("-----------------------------------------------------------")
# Out:
# Question ===> What is a court of inquiry?
# According to App A it is not mad to report
# -----------------------------------------------------------
# Question ===> Give definition of court of inquiry?
# According to App A it is not mad to report
# -----------------------------------------------------------
# Question ===> What are the cases which are necessarily required to be investigated by a court of inquiry?
# According to App A it is not mad to report
# -----------------------------------------------------------
# Question ===> Mandotory cases to be tries under court of inquiry?
# According to App A it is not mad to report
# -----------------------------------------------------------
# Question ===> Which cases can be tried under court of inquiry?
# According to App A it is not mad to report
# -----------------------------------------------------------
# Question ===> Can AWL/OSL beyond 30 days be tried by court of inquiry?
# According to App A it is not mad to report
# ...
